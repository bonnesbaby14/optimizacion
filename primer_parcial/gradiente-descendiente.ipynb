# %%
import math
def parcial_x(x,y):
    return 2*math.pow(math.e,-(math.pow(x,2)+3*math.pow(y,2)))*x
    

def parcial_y(x,y):
       return 6*y*math.pow(math.e,-(math.pow(x,2)+3*math.pow(y,2)))
   
   
def gradiente(x,y,mu):
    
    gx=parcial_x(x,y)
    gy=parcial_y(x,y)
    x=x- mu * gx
    y=y- mu * gy
    
    return (x,y)

x=.5
y=.5

print(parcial_x(.4,.3))
print("---")

for i in range(1000):
    print(x,y)
    x,y=gradiente(x,y,.005)
# Out:
# 0.5204072757786532
# ---
# 0.5 0.5
# 0.4981606027941428 0.4944818083824284
# 0.49629412789353794 0.48892373406477957
# 0.4944003921725208 0.4833268977049698
# 0.4924792323162284 0.4776925075545686
# 0.49053050613979476 0.47202186096072357
# 0.48855409390993093 0.46631634560282653
# 0.4865498996615054 0.46057744043682286
# 0.484517852501163 0.4548067163202922
# 0.48245790788947684 0.4490058362919938
# 0.48037004889263313 0.4431765554805017
# 0.4782542873942093 0.4373207206178707
# 0.4761106652572393 0.43144026913600386
# 0.47393925542647675 0.42553722782553927
# 0.47174016296057875 0.41961371103964956
# 0.46951352598385276 0.413671918428151
# 0.46725951654724773 0.4077141321907362
# 0.46497834138843575 0.40174271384196053
# 0.46267024258113226 0.3957601004847921
# 0.46033549806424545 0.38976880059404484
# 0.4579744220420321 0.3837713893157969
# 0.45558736524717125 0.3777705032939
# 0.45317471505954166 0.371768835039831
# 0.45073689547450335 0.36576912686735785
# ...
